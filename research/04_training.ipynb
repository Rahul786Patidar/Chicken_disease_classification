# %%
# Out:
# 'c:\\Users\\Patidar\\VS_CODE\\Chicken_disease_classification\\research'

# %%
# Out:
# 'c:\\Users\\Patidar\\VS_CODE\\Chicken_disease_classification'

# %%
# Out:
# [2024-09-02 19:28:45,623: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2024-09-02 19:28:46,043: INFO: common: yaml file: params.yaml loaded successfully]
# [2024-09-02 19:28:46,269: INFO: common: created directory at:artifacts]
# [2024-09-02 19:28:46,550: INFO: common: created directory at:artifacts\prepare_callbacks\checkpoint_dir]
# [2024-09-02 19:28:46,576: INFO: common: created directory at:artifacts\prepare_callbacks\tensorboard_log_dir]
# [2024-09-02 19:28:47,388: INFO: common: created directory at:artifacts\training]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 15
#      11     training.train(
#      12         callback_list= callback_list
#      13     )
#      14 except Exception as e:
# ---> 15     raise e
#
# Cell In[97], line 9
#       7 training_config = config.get_training_config()
# ...
